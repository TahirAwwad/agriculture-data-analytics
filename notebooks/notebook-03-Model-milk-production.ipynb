# %% [markdown]
# # Read full dataset of Agriculture Production since 1991 to 2020

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../assets/TA_inputoutputvalue_1990_2021_CSO.csv")
print("data dimensions \n",df.shape)
print()
print("data column info \n",df.info)
# Out:
# data dimensions
#  (32, 57)
#
# data column info
#  <bound method DataFrame.info of     Unnamed: 0  Year          UNIT  Agricultural Output at Basic Prices  \
# 0            0  1990  Euro Million                               5200.0
# 1            1  1991  Euro Million                               4994.4
# 2            2  1992  Euro Million                               5374.0
# 3            3  1993  Euro Million                               5625.9
# 4            4  1994  Euro Million                               5781.5
# 5            5  1995  Euro Million                               6035.5
# 6            6  1996  Euro Million                               6134.7
# 7            7  1997  Euro Million                               5753.1
# 8            8  1998  Euro Million                               5831.7
# 9            9  1999  Euro Million                               5651.4
# 10          10  2000  Euro Million                               5985.5
# 11          11  2001  Euro Million                               6066.8
# 12          12  2002  Euro Million                               5836.1
# 13          13  2003  Euro Million                               5979.1
# 14          14  2004  Euro Million                               6156.9
# 15          15  2005  Euro Million                               5710.7
# 16          16  2006  Euro Million                               5466.7
# 17          17  2007  Euro Million                               5975.4
# 18          18  2008  Euro Million                               6143.0
# 19          19  2009  Euro Million                               5014.0
# 20          20  2010  Euro Million                               5822.1
# 21          21  2011  Euro Million                               6576.2
# 22          22  2012  Euro Million                               6837.5
# 23          23  2013  Euro Million                               7671.6
# 24          24  2014  Euro Million                               7293.9
# 25          25  2015  Euro Million                               7404.2
# 26          26  2016  Euro Million                               7444.2
# 27          27  2017  Euro Million                               8476.4
# 28          28  2018  Euro Million                               8663.7
# 29          29  2019  Euro Million                               8516.4
# 30          30  2020  Euro Million                               8908.3
# 31          31  2021  Euro Million                               9972.9
#
#     All Cereals  All Crops  All Livestock  All Livestock Products  \
# 0         216.7     1123.5         2201.9                  1360.0
# 1         218.6     1127.3         2114.0                  1301.9
# 2         235.4     1154.4         2262.5                  1410.7
# 3         165.7     1101.7         2449.6                  1476.7
# 4         127.3     1157.0         2319.3                  1487.6
# 5         159.4     1217.2         2349.1                  1580.8
# 6         200.9     1268.7         2318.2                  1573.9
# 7         160.0     1102.6         2205.5                  1450.9
# 8         143.1     1127.9         2152.5                  1465.9
# 9         164.1     1184.3         2067.9                  1438.1
# 10        185.1     1228.6         2170.6                  1484.3
# 11        169.8     1322.5         2175.1                  1604.2
# 12        141.9     1245.3         2014.8                  1451.0
# 13        171.7     1302.7         2065.4                  1470.6
# 14        181.4     1350.6         2212.8                  1459.3
# 15        125.7     1378.1         2273.8                  1389.5
# 16        159.7     1461.3         2386.8                  1380.2
# 17        241.8     1632.7         2378.7                  1716.1
# 18        197.0     1657.1         2541.7                  1681.5
# 19        107.0     1377.9         2222.8                  1153.9
# 20        192.9     1670.0         2259.6                  1583.9
# 21        290.1     1715.9         2644.8                  1891.1
# 22        334.9     1784.5         3065.0                  1692.3
# 23        289.6     2066.4         3147.6                  2132.3
# 24        280.5     1747.5         3070.1                  2151.3
# 25        262.7     1737.3         3452.5                  1949.4
# 26        230.8     1767.4         3440.2                  1857.8
# 27        237.2     1824.6         3592.4                  2668.7
# 28        288.4     2126.0         3431.4                  2639.2
# 29        327.2     1893.6         3372.4                  2689.7
# 30        289.5     1942.9         3591.8                  2832.0
# 31        421.9     2120.5         3892.0                  3460.0
#
#     All Livestock Products - Milk  \
# 0                          1316.3
# 1                          1258.9
# 2                          1373.1
# 3                          1439.0
# 4                          1446.2
# 5                          1538.5
# 6                          1536.0
# 7                          1414.5
# 8                          1431.2
# 9                          1408.8
# 10                         1447.1
# 11                         1566.1
# 12                         1413.0
# 13                         1431.3
# 14                         1417.8
# 15                         1342.1
# 16                         1332.5
# 17                         1667.5
# 18                         1628.1
# 19                         1106.5
# 20                         1541.9
# 21                         1834.8
# 22                         1629.8
# 23                         2073.4
# 24                         2093.1
# 25                         1881.1
# 26                         1790.8
# 27                         2594.1
# 28                         2556.7
# 29                         2608.6
# 30                         2752.7
# 31                         3376.6
#
#     All Livestock Products Other Products (excluding Milk)  ...  \
# 0                                                43.7       ...
# 1                                                43.0       ...
# 2                                                37.6       ...
# 3                                                37.7       ...
# 4                                                41.4       ...
# 5                                                42.3       ...
# 6                                                37.9       ...
# 7                                                36.3       ...
# 8                                                34.7       ...
# 9                                                29.3       ...
# 10                                               37.2       ...
# 11                                               38.1       ...
# 12                                               37.9       ...
# 13                                               39.3       ...
# 14                                               41.6       ...
# 15                                               47.3       ...
# 16                                               47.7       ...
# 17                                               48.6       ...
# 18                                               53.4       ...
# 19                                               47.4       ...
# 20                                               42.0       ...
# 21                                               56.3       ...
# 22                                               62.6       ...
# 23                                               58.9       ...
# 24                                               58.2       ...
# 25                                               68.3       ...
# 26                                               67.0       ...
# 27                                               74.6       ...
# 28                                               82.6       ...
# 29                                               81.1       ...
# 30                                               79.2       ...
# 31                                               83.4       ...
#
#     Livestock - Horses  Livestock - Pig  Livestock - Poultry  \
# 0                 83.2            237.2                117.1
# 1                 70.2            242.1                125.5
# 2                 61.4            280.4                124.5
# 3                 84.5            257.9                116.0
# 4                 75.9            264.5                134.6
# 5                 70.1            295.5                133.8
# 6                 96.9            356.5                140.4
# 7                106.9            337.0                149.1
# 8                128.7            282.6                142.2
# 9                150.0            251.4                137.8
# 10               164.4            296.7                124.0
# 11               146.5            346.1                137.7
# 12               200.7            300.9                132.1
# 13               204.3            285.1                138.7
# 14               217.6            297.5                151.2
# 15               234.0            292.9                146.5
# 16               263.5            321.5                114.3
# 17               269.3            288.6                133.0
# 18               228.5            330.1                122.7
# 19               172.7            300.0                115.1
# 20               145.9            333.7                112.2
# 21               135.6            394.2                130.1
# 22               166.7            441.5                132.9
# 23               186.5            475.7                129.9
# 24               221.7            471.3                133.3
# 25               247.3            456.3                142.2
# 26               270.5            465.6                159.5
# 27               287.4            516.8                163.1
# 28               306.4            459.1                159.0
# 29               255.5            543.0                169.2
# 30               216.1            601.9                180.0
# 31               257.2            565.1                187.9
#
#     Livestock - Sheep  Net Value Added at Basic Prices  Operating Surplus  \
# 0               188.8                           2306.3             1943.5
# 1               198.9                           2126.2             1774.0
# 2               192.8                           2484.9             2179.4
# 3               232.4                           2560.6             2247.9
# 4               230.2                           2513.7             2278.5
# 5               190.7                           2612.3             2375.3
# 6               241.8                           2518.5             2423.2
# 7               230.0                           2291.0             2233.1
# 8               214.0                           2270.1             2229.1
# 9               198.0                           1973.9             1930.5
# 10              203.5                           2188.4             2163.0
# 11              284.4                           1979.6             2177.1
# 12              202.2                           1786.8             2024.8
# 13              193.3                           1874.6             2060.7
# 14              200.4                           1989.0             2177.4
# 15              194.2                           1318.4             2589.9
# 16              193.1                            784.0             2185.6
# 17              184.5                           1045.8             2442.0
# 18              173.8                            673.6             2118.3
# 19              159.4                             43.8             1429.0
# 20              165.6                            654.9             1841.5
# 21              189.8                           1159.5             2515.8
# 22              204.4                           1066.7             2280.7
# 23              203.8                           1289.7             2355.9
# 24              231.6                           1411.1             2441.2
# 25              245.2                           1666.3             2587.2
# 26              255.7                           1545.6             2626.0
# 27              262.9                           2309.2             3422.1
# 28              258.8                           1708.0             2823.0
# 29              260.8                           1881.1             2924.8
# 30              303.3                           2233.8             3262.8
# 31              361.9                           2906.0             3851.7
#
#     Other Subsidies Less Taxes on Production  \
# 0                                       14.8
# 1                                       10.3
# 2                                       31.4
# 3                                       26.3
# 4                                      110.0
# 5                                      125.8
# 6                                      247.9
# 7                                      290.4
# 8                                      318.9
# 9                                      331.6
# 10                                     356.5
# 11                                     569.0
# 12                                     616.1
# 13                                     577.2
# 14                                     592.4
# 15                                    1680.5
# 16                                    1826.9
# 17                                    1844.9
# 18                                    1880.9
# 19                                    1812.9
# 20                                    1651.3
# 21                                    1831.7
# 22                                    1682.0
# 23                                    1557.6
# 24                                    1525.8
# 25                                    1409.9
# 26                                    1593.4
# 27                                    1638.5
# 28                                    1682.8
# 29                                    1630.0
# 30                                    1646.5
# 31                                    1600.2
#
#     Subsidies less Taxes on Products  Subsidies on Products  Taxes on Products
# 0                              333.9                  408.9               75.0
# 1                              279.1                  357.3               78.2
# 2                              366.6                  446.0               79.5
# 3                              398.4                  466.4               68.0
# 4                              612.3                  666.0               53.7
# 5                              676.0                  735.6               59.6
# 6                              753.0                  806.0               53.0
# 7                              769.0                  808.7               39.8
# 8                              860.2                  899.6               39.4
# 9                              715.8                  743.7               27.9
# 10                             843.8                  876.7               32.8
# 11                             685.8                  710.8               25.0
# 12                             876.7                  904.1               27.4
# 13                             892.5                  928.4               35.8
# 14                             873.0                  912.1               39.1
# 15                             399.2                  453.4               54.2
# 16                             -33.1                    3.8               36.8
# 17                             -40.4                    0.7               41.1
# 18                             -18.3                   32.4               50.7
# 19                              -9.3                   30.0               39.3
# 20                             -10.5                   31.8               42.3
# 21                             -11.0                   31.0               42.0
# 22                             -28.1                   28.5               56.7
# 23                             -40.5                    9.4               49.8
# 24                             -33.7                   28.8               62.5
# 25                             -82.9                   43.2              126.2
# 26                               7.1                   55.9               48.8
# 27                              11.0                   60.5               49.5
# 28                              13.9                   65.1               51.2
# 29                              99.5                  150.6               51.1
# 30                              94.6                  147.2               52.6
# 31                              53.4                    NaN                NaN
#
# [32 rows x 57 columns]>

# %% [markdown]
# # Production of Milk

# %%
## Extract milk production dataset
# drop redundunt columns
df = df.drop('Unnamed: 0',axis=1)

# extract milk dataset
df_milk = df[['Year',
              'UNIT',
              'All Livestock Products - Milk',
              'Taxes on Products',
              'Subsidies on Products',
              'Compensation of Employees',
              'Contract Work',
              'Entrepreneurial Income',
              'Factor Income',
              'Fixed Capital Consumption - Farm Buildings',
              'Fixed Capital Consumption - Machinery, Equipment, etc',
              'Interest less FISIM',
              'Operating Surplus',
              'Livestock - Cattle',
              'Livestock - Sheep',
              'Land Rental',
              'Intermediate Consumption - Contract Work',
              'Intermediate Consumption - Crop Protection Products',
              'Intermediate Consumption - Energy and Lubricants',
              'Intermediate Consumption - Feeding Stuffs',
              'Intermediate Consumption - Fertilisers',
              'Intermediate Consumption - Financial Intermediation Services Indirect',
              'Intermediate Consumption - Forage Plants',
              'Intermediate Consumption - Maintenance and Repairs',
              'Intermediate Consumption - Seeds',
              'Intermediate Consumption - Services',
              'Intermediate Consumption - Veterinary Expenses',
              'Intermediate Consumption - Other Goods (Detergents, Small Tools, etc)',
              'Intermediate Consumption - Other Goods and Services'
              
             ]]
# Assign year as index
df_milk.set_index('Year',drop=True,inplace=True)

print("Milk production dataset dimenssions \n", df_milk.shape)

# %%
df_milk = df[['Year',
              'UNIT',
              'All Livestock Products - Milk',
              'Taxes on Products',
              'Subsidies on Products',
              'Compensation of Employees',
              'Contract Work',
              'Entrepreneurial Income',
              'Factor Income',
              'Fixed Capital Consumption - Farm Buildings',
              'Fixed Capital Consumption - Machinery, Equipment, etc',
              'Interest less FISIM',
              'Operating Surplus',
              'Livestock - Cattle',
              'Livestock - Sheep',
              'Land Rental',
              'Intermediate Consumption - Contract Work',
              'Intermediate Consumption - Crop Protection Products',
              'Intermediate Consumption - Energy and Lubricants',
              'Intermediate Consumption - Feeding Stuffs',
              'Intermediate Consumption - Fertilisers',
              'Intermediate Consumption - Financial Intermediation Services Indirect',
              'Intermediate Consumption - Forage Plants',
              'Intermediate Consumption - Maintenance and Repairs',
              'Intermediate Consumption - Seeds',
              'Intermediate Consumption - Services',
              'Intermediate Consumption - Veterinary Expenses',
              'Intermediate Consumption - Other Goods (Detergents, Small Tools, etc)',
              'Intermediate Consumption - Other Goods and Services'
              
             ]]

# %% [markdown]
# ## Define 20% Training set 80% Test set

# %%
# define target & feature variables

X = df_milk.iloc[:,2:].values
Y = df_milk.iloc[:,1].values.reshape(-1,1)
print(np.shape(X))
print(np.shape(Y))

# split train test split 20
from sklearn.model_selection import train_test_split
X_train, X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=2021)
# Out:
# (32, 26)
# (32, 1)

# %% [markdown]
# ## Model 1 RandomForest Regressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model_milk = RandomForestRegressor(random_state=2021)

# %%
params_rf_milk = {'n_estimators':[100,200,500]
            ,'max_features':['auto','sqrt']
            }

# %%
GS_rf_milk = GridSearchCV(estimator= rf_model_milk,
                     param_grid= params_rf_milk
                     )

# %%
# np.isnan(X_train).sum()
# np.nan_to_num(X_train)
# np.nan_to_num(Y_train)
GS_rf_milk.fit(X_train,Y_train)
# Out:
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 814, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "/Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/admin/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:918: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan]
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-dd882d60784d> in <module>
#       2 # np.nan_to_num(X_train)
#       3 # np.nan_to_num(Y_train)
# ----> 4 GS_rf_milk.fit(X_train,Y_train)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     878             refit_start_time = time.time()
#     879             if y is not None:
# --> 880                 self.best_estimator_.fit(X, y, **fit_params)
#     881             else:
#     882                 self.best_estimator_.fit(X, **fit_params)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     302                 "sparse multilabel-indicator for y is not supported."
#     303             )
# --> 304         X, y = self._validate_data(X, y, multi_output=True,
#     305                                    accept_sparse="csc", dtype=DTYPE)
#     306         if sample_weight is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     812         raise ValueError("y cannot be None")
#     813
# --> 814     X = check_array(X, accept_sparse=accept_sparse,
#     815                     accept_large_sparse=accept_large_sparse,
#     816                     dtype=dtype, order=order, copy=copy,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     661
#     662         if force_all_finite:
# --> 663             _assert_all_finite(array,
#     664                                allow_nan=force_all_finite == 'allow-nan')
#     665
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
# print best model
print(GS_rf_milk.best_estimator_)
print('Best model score',GS_rf_milk.best_score_)
# Out:
# RandomForestRegressor(random_state=20)
# Best model score nan

# %% [markdown]
# ## Model 2 XGBOOST Regressor

# %%
# xgboost
from xgboost import XGBRegressor
xgb_model_milk = XGBRegressor(random_state=2021)

# %%
# make a search space of parameters to loop over

params_xgb_milk = {'n_estimators':[20,40,80,160,340,500],
             'max_depth':[3,6,9],
             'gamma':[0.01,0.1],
             'learning_rate':[0.001,0.01,0.1,1]
             }

# %%
GS_xgb_milk = GridSearchCV(estimator=xgb_model_milk,
                     param_grid=params_xgb_milk,
                     #n_jobs=-1,
                     scoring=['r2','neg_root_mean_squared_error'],
                     refit= 'r2',
                     cv=5,
                     verbose=4
                     )

# %%
GS_xgb_milk.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-1719.914) r2: (test=-14.187) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-1566.839) r2: (test=-33.486) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-2071.229) r2: (test=-6.465) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-2077.487) r2: (test=-13.834) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-1585.432) r2: (test=-49.993) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-1689.258) r2: (test=-13.651) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-1537.104) r2: (test=-32.190) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-2041.490) r2: (test=-6.252) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-2046.958) r2: (test=-13.401) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-1555.068) r2: (test=-48.059) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-1632.439) r2: (test=-12.682) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-1479.245) r2: (test=-29.738) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-1983.885) r2: (test=-5.849) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-1987.717) r2: (test=-12.580) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-1496.025) r2: (test=-44.404) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-1524.862) r2: (test=-10.938) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-1371.015) r2: (test=-25.405) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-1875.857) r2: (test=-5.123) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-1873.511) r2: (test=-11.064) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-1384.416) r2: (test=-37.882) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-1304.492) r2: (test=-7.737) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-1164.893) r2: (test=-18.062) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-1657.422) r2: (test=-3.780) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-1620.849) r2: (test=-8.030) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-1162.349) r2: (test=-26.409) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-1132.534) r2: (test=-5.585) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-1007.256) r2: (test=-13.252) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-1490.157) r2: (test=-2.864) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-1427.106) r2: (test=-6.000) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-995.013) r2: (test=-19.085) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-1719.914) r2: (test=-14.187) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-1566.839) r2: (test=-33.486) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-2071.229) r2: (test=-6.465) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-2077.487) r2: (test=-13.834) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-1585.432) r2: (test=-49.993) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-1689.258) r2: (test=-13.651) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-1537.104) r2: (test=-32.190) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-2041.490) r2: (test=-6.252) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-2046.958) r2: (test=-13.401) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-1555.068) r2: (test=-48.059) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-1632.439) r2: (test=-12.682) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-1479.245) r2: (test=-29.738) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-1983.885) r2: (test=-5.849) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-1987.717) r2: (test=-12.580) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-1496.025) r2: (test=-44.404) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-1524.862) r2: (test=-10.938) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-1371.015) r2: (test=-25.405) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-1875.857) r2: (test=-5.123) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-1873.511) r2: (test=-11.064) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-1384.416) r2: (test=-37.882) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-1304.492) r2: (test=-7.737) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-1164.893) r2: (test=-18.062) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-1657.422) r2: (test=-3.780) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-1620.849) r2: (test=-8.030) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-1162.349) r2: (test=-26.409) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-1132.534) r2: (test=-5.585) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-1007.256) r2: (test=-13.252) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-1490.157) r2: (test=-2.864) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-1427.106) r2: (test=-6.000) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-995.013) r2: (test=-19.085) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-1719.914) r2: (test=-14.187) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-1566.839) r2: (test=-33.486) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-2071.229) r2: (test=-6.465) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-2077.487) r2: (test=-13.834) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-1585.432) r2: (test=-49.993) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-1689.258) r2: (test=-13.651) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-1537.104) r2: (test=-32.190) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-2041.490) r2: (test=-6.252) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-2046.958) r2: (test=-13.401) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-1555.068) r2: (test=-48.059) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-1632.439) r2: (test=-12.682) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-1479.245) r2: (test=-29.738) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-1983.885) r2: (test=-5.849) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-1987.717) r2: (test=-12.580) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-1496.025) r2: (test=-44.404) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-1524.862) r2: (test=-10.938) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-1371.015) r2: (test=-25.405) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-1875.857) r2: (test=-5.123) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-1873.511) r2: (test=-11.064) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-1384.416) r2: (test=-37.882) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-1304.492) r2: (test=-7.737) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-1164.893) r2: (test=-18.062) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-1657.422) r2: (test=-3.780) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-1620.849) r2: (test=-8.030) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-1162.349) r2: (test=-26.409) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-1132.534) r2: (test=-5.585) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-1007.256) r2: (test=-13.252) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-1490.157) r2: (test=-2.864) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-1427.106) r2: (test=-6.000) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-995.013) r2: (test=-19.085) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-1472.910) r2: (test=-10.138) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-1320.170) r2: (test=-23.483) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-1824.311) r2: (test=-4.791) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-1813.650) r2: (test=-10.306) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-1330.828) r2: (test=-34.930) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-1236.299) r2: (test=-6.847) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-1100.470) r2: (test=-16.012) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-1590.027) r2: (test=-3.399) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-1544.109) r2: (test=-7.195) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-1094.871) r2: (test=-23.319) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-854.619) r2: (test=-2.750) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-765.723) r2: (test=-7.236) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-1233.907) r2: (test=-1.649) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-1116.042) r2: (test=-3.281) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-747.977) r2: (test=-10.350) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-414.072) r2: (test=0.120) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-381.344) r2: (test=-1.043) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-813.342) r2: (test=-0.151) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-561.985) r2: (test=-0.086) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-357.010) r2: (test=-1.586) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-163.534) r2: (test=0.863) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-153.304) r2: (test=0.670) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-469.812) r2: (test=0.616) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-197.577) r2: (test=0.866) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-111.484) r2: (test=0.748) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-140.079) r2: (test=0.899) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-138.570) r2: (test=0.730) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-379.871) r2: (test=0.749) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-163.146) r2: (test=0.909) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-99.698) r2: (test=0.798) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-1472.910) r2: (test=-10.138) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-1320.170) r2: (test=-23.483) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-1824.311) r2: (test=-4.791) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-1813.650) r2: (test=-10.306) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-1330.828) r2: (test=-34.930) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-1236.299) r2: (test=-6.847) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-1100.470) r2: (test=-16.012) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-1590.027) r2: (test=-3.399) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-1544.109) r2: (test=-7.195) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-1094.871) r2: (test=-23.319) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-854.619) r2: (test=-2.750) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-765.723) r2: (test=-7.236) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-1233.907) r2: (test=-1.649) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-1116.042) r2: (test=-3.281) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-747.977) r2: (test=-10.350) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-414.072) r2: (test=0.120) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-381.344) r2: (test=-1.043) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-813.342) r2: (test=-0.151) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-561.985) r2: (test=-0.086) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-357.010) r2: (test=-1.586) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-162.801) r2: (test=0.864) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-152.477) r2: (test=0.673) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-470.049) r2: (test=0.616) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-197.637) r2: (test=0.866) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-111.484) r2: (test=0.748) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-130.016) r2: (test=0.913) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-137.181) r2: (test=0.736) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-382.802) r2: (test=0.745) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-162.988) r2: (test=0.909) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-99.815) r2: (test=0.798) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-1472.910) r2: (test=-10.138) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-1320.170) r2: (test=-23.483) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-1824.311) r2: (test=-4.791) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-1813.650) r2: (test=-10.306) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-1330.828) r2: (test=-34.930) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-1236.299) r2: (test=-6.847) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-1100.470) r2: (test=-16.012) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-1590.027) r2: (test=-3.399) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-1544.109) r2: (test=-7.195) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-1094.871) r2: (test=-23.319) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-854.619) r2: (test=-2.750) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-765.723) r2: (test=-7.236) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-1233.907) r2: (test=-1.649) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-1116.042) r2: (test=-3.281) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-747.977) r2: (test=-10.350) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-414.072) r2: (test=0.120) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-381.344) r2: (test=-1.043) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-813.342) r2: (test=-0.151) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-561.985) r2: (test=-0.086) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-357.010) r2: (test=-1.586) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-162.801) r2: (test=0.864) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-152.477) r2: (test=0.673) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-470.049) r2: (test=0.616) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-197.637) r2: (test=0.866) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-111.484) r2: (test=0.748) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-130.016) r2: (test=0.913) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-137.220) r2: (test=0.735) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-382.781) r2: (test=0.745) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-162.988) r2: (test=0.909) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-99.815) r2: (test=0.798) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-280.171) r2: (test=0.597) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-259.946) r2: (test=0.051) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-670.443) r2: (test=0.218) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-366.616) r2: (test=0.538) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-250.556) r2: (test=-0.274) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-147.131) r2: (test=0.889) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-138.527) r2: (test=0.730) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-417.808) r2: (test=0.696) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-178.601) r2: (test=0.890) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-104.378) r2: (test=0.779) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-132.116) r2: (test=0.910) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-133.635) r2: (test=0.749) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-340.328) r2: (test=0.798) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-145.854) r2: (test=0.927) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-98.934) r2: (test=0.801) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-131.793) r2: (test=0.911) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-132.973) r2: (test=0.752) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-334.705) r2: (test=0.805) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-141.682) r2: (test=0.931) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-97.506) r2: (test=0.807) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-131.776) r2: (test=0.911) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-132.989) r2: (test=0.752) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-334.537) r2: (test=0.805) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-141.682) r2: (test=0.931) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-97.493) r2: (test=0.807) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-131.776) r2: (test=0.911) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-132.989) r2: (test=0.752) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-334.537) r2: (test=0.805) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-141.682) r2: (test=0.931) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-97.493) r2: (test=0.807) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-280.171) r2: (test=0.597) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-259.946) r2: (test=0.051) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-670.443) r2: (test=0.218) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-366.616) r2: (test=0.538) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-250.556) r2: (test=-0.274) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-144.539) r2: (test=0.893) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-139.069) r2: (test=0.728) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-418.410) r2: (test=0.695) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-178.677) r2: (test=0.890) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-103.944) r2: (test=0.781) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-128.110) r2: (test=0.916) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-136.768) r2: (test=0.737) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-322.694) r2: (test=0.819) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-144.244) r2: (test=0.928) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-94.707) r2: (test=0.818) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-127.781) r2: (test=0.916) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-136.663) r2: (test=0.738) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-309.761) r2: (test=0.833) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-141.600) r2: (test=0.931) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-94.227) r2: (test=0.820) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-127.775) r2: (test=0.916) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-136.663) r2: (test=0.738) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-309.599) r2: (test=0.833) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-141.561) r2: (test=0.931) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-94.226) r2: (test=0.820) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-127.775) r2: (test=0.916) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-136.663) r2: (test=0.738) total time=   0.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-309.599) r2: (test=0.833) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-141.561) r2: (test=0.931) total time=   0.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-94.226) r2: (test=0.820) total time=   0.3s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-280.171) r2: (test=0.597) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-259.946) r2: (test=0.051) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-670.443) r2: (test=0.218) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-366.616) r2: (test=0.538) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-250.556) r2: (test=-0.274) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-144.539) r2: (test=0.893) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-139.069) r2: (test=0.728) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-418.410) r2: (test=0.695) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-178.677) r2: (test=0.890) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-103.944) r2: (test=0.781) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-127.631) r2: (test=0.916) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-136.768) r2: (test=0.737) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-322.487) r2: (test=0.819) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-144.243) r2: (test=0.928) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-94.135) r2: (test=0.820) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-127.208) r2: (test=0.917) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-136.663) r2: (test=0.738) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-309.787) r2: (test=0.833) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-141.600) r2: (test=0.931) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-93.470) r2: (test=0.823) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-127.202) r2: (test=0.917) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-136.663) r2: (test=0.738) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-309.625) r2: (test=0.833) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-141.555) r2: (test=0.931) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-93.466) r2: (test=0.823) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-127.202) r2: (test=0.917) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-136.663) r2: (test=0.738) total time=   0.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-309.625) r2: (test=0.833) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-141.555) r2: (test=0.931) total time=   0.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-93.466) r2: (test=0.823) total time=   0.3s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-59.514) r2: (test=0.982) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-188.421) r2: (test=0.501) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-420.426) r2: (test=0.692) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-373.389) r2: (test=0.521) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-160.357) r2: (test=0.478) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-59.514) r2: (test=0.982) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-188.421) r2: (test=0.501) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-420.426) r2: (test=0.692) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-373.389) r2: (test=0.521) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-160.357) r2: (test=0.478) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-59.514) r2: (test=0.982) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-188.421) r2: (test=0.501) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-420.426) r2: (test=0.692) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-373.389) r2: (test=0.521) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-160.357) r2: (test=0.478) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-59.514) r2: (test=0.982) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-188.421) r2: (test=0.501) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-420.426) r2: (test=0.692) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-373.389) r2: (test=0.521) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-160.357) r2: (test=0.478) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-59.514) r2: (test=0.982) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-188.421) r2: (test=0.501) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-420.426) r2: (test=0.692) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-373.389) r2: (test=0.521) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-160.357) r2: (test=0.478) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-59.514) r2: (test=0.982) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-188.421) r2: (test=0.501) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-420.426) r2: (test=0.692) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-373.389) r2: (test=0.521) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-160.357) r2: (test=0.478) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-62.138) r2: (test=0.980) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-240.123) r2: (test=0.190) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-383.943) r2: (test=0.743) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-378.726) r2: (test=0.507) total time=   0.0s
# ...
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-127.203) r2: (test=0.917) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-136.590) r2: (test=0.738) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-309.772) r2: (test=0.833) total time=   0.3s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-141.576) r2: (test=0.931) total time=   0.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-93.556) r2: (test=0.822) total time=   0.3s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-59.475) r2: (test=0.982) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-188.432) r2: (test=0.501) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-420.475) r2: (test=0.692) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-373.435) r2: (test=0.521) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=20; neg_root_mean_squared_error: (test=-160.335) r2: (test=0.478) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-59.475) r2: (test=0.982) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-188.432) r2: (test=0.501) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-420.475) r2: (test=0.692) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-373.435) r2: (test=0.521) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=40; neg_root_mean_squared_error: (test=-160.335) r2: (test=0.478) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-59.475) r2: (test=0.982) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-188.432) r2: (test=0.501) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-420.475) r2: (test=0.692) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-373.435) r2: (test=0.521) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=80; neg_root_mean_squared_error: (test=-160.335) r2: (test=0.478) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-59.475) r2: (test=0.982) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-188.432) r2: (test=0.501) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-420.475) r2: (test=0.692) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-373.435) r2: (test=0.521) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=160; neg_root_mean_squared_error: (test=-160.335) r2: (test=0.478) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-59.475) r2: (test=0.982) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-188.432) r2: (test=0.501) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-420.475) r2: (test=0.692) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-373.435) r2: (test=0.521) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=340; neg_root_mean_squared_error: (test=-160.335) r2: (test=0.478) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-59.475) r2: (test=0.982) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-188.432) r2: (test=0.501) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-420.475) r2: (test=0.692) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-373.435) r2: (test=0.521) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-160.335) r2: (test=0.478) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-62.145) r2: (test=0.980) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-240.173) r2: (test=0.190) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-383.992) r2: (test=0.743) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-379.194) r2: (test=0.506) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=20; neg_root_mean_squared_error: (test=-196.597) r2: (test=0.216) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-62.145) r2: (test=0.980) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-240.173) r2: (test=0.190) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-383.992) r2: (test=0.743) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-379.194) r2: (test=0.506) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=40; neg_root_mean_squared_error: (test=-196.597) r2: (test=0.216) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-62.145) r2: (test=0.980) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-240.173) r2: (test=0.190) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-383.992) r2: (test=0.743) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-379.194) r2: (test=0.506) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=80; neg_root_mean_squared_error: (test=-196.597) r2: (test=0.216) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-62.145) r2: (test=0.980) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-240.173) r2: (test=0.190) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-383.992) r2: (test=0.743) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-379.194) r2: (test=0.506) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=160; neg_root_mean_squared_error: (test=-196.597) r2: (test=0.216) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-62.145) r2: (test=0.980) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-240.173) r2: (test=0.190) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-383.992) r2: (test=0.743) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-379.194) r2: (test=0.506) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=340; neg_root_mean_squared_error: (test=-196.597) r2: (test=0.216) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-62.145) r2: (test=0.980) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-240.173) r2: (test=0.190) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-383.992) r2: (test=0.743) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-379.194) r2: (test=0.506) total time=   0.3s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-196.597) r2: (test=0.216) total time=   0.3s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-61.971) r2: (test=0.980) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-238.403) r2: (test=0.202) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-387.297) r2: (test=0.739) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-379.309) r2: (test=0.505) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=20; neg_root_mean_squared_error: (test=-205.499) r2: (test=0.143) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-61.971) r2: (test=0.980) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-238.403) r2: (test=0.202) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-387.297) r2: (test=0.739) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-379.309) r2: (test=0.505) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=40; neg_root_mean_squared_error: (test=-205.499) r2: (test=0.143) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-61.971) r2: (test=0.980) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-238.403) r2: (test=0.202) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-387.297) r2: (test=0.739) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-379.309) r2: (test=0.505) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=80; neg_root_mean_squared_error: (test=-205.499) r2: (test=0.143) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-61.971) r2: (test=0.980) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-238.403) r2: (test=0.202) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-387.297) r2: (test=0.739) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-379.309) r2: (test=0.505) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=160; neg_root_mean_squared_error: (test=-205.499) r2: (test=0.143) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-61.971) r2: (test=0.980) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-238.403) r2: (test=0.202) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-387.297) r2: (test=0.739) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-379.309) r2: (test=0.505) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=340; neg_root_mean_squared_error: (test=-205.499) r2: (test=0.143) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-61.971) r2: (test=0.980) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-238.403) r2: (test=0.202) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-387.297) r2: (test=0.739) total time=   0.3s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-379.309) r2: (test=0.505) total time=   0.3s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-205.499) r2: (test=0.143) total time=   0.3s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     enable_categorical=False, gamma=None,
#                                     gpu_id=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, monotone_constraints=None,
#                                     n...
#                                     num_parallel_tree=None, predictor=None,
#                                     random_state=2021, reg_alpha=None,
#                                     reg_lambda=None, scale_pos_weight=None,
#                                     subsample=None, tree_method=None,
#                                     validate_parameters=None, verbosity=None),
#              param_grid={'gamma': [0.01, 0.1],
#                          'learning_rate': [0.001, 0.01, 0.1, 1],
#                          'max_depth': [3, 6, 9],
#                          'n_estimators': [20, 40, 80, 160, 340, 500]},
#              refit='r2', scoring=['r2', 'neg_root_mean_squared_error'],
#              verbose=4)

# %%
# print best model
print(GS_xgb_milk.best_estimator_)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0.01, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#              max_depth=9, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=340, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=2021,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# print best parameters
print('Best model Parameters',GS_xgb_milk.best_params_)
# best score
print('Best model R2 score',GS_xgb_milk.best_score_)

# write the Grid Search results to csv to choose best model with least resource consumption
GS_xgb_df_milk = pd.DataFrame(GS_xgb_milk.cv_results_)
GS_xgb_df_milk = GS_xgb_df_milk.sort_values('rank_test_r2')
GS_xgb_df_milk.to_csv('GS_xgb_milk_results.csv')
# Out:
# Best model Parameters {'gamma': 0.01, 'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 340}
# Best model R2 score 0.8483316258834732

# %%
predict(X_test)
